# %% [markdown]
# # Implementation of ANN on Iris Dataset
#
#   The algorithm used here is Artificial Neural Network(ANN).
#   The term "Artificial Neural Network" is derived from Biological neural networks that develop the structure of a human brain. Similar to the human brain that has neurons interconnected to one another, artificial neural networks also have neurons that are interconnected to one another in various layers of the networks. These neurons are known as nodes.
#   ![ann.png](data:image/png;base64,...)

# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library

# %%
#Reading data 
data=pd.read_csv("/content/drive/MyDrive/Happy Monk/Iris.csv")
print("Describing the data: ",data.describe())
print("Info of the data:",data.info())
# Out:
# Describing the data:                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# Info of the data: None

# %%
print("10 first samples of the dataset:",data.head(10))
print("10 last samples of the dataset:",data.tail(10))
# Out:
# 10 first samples of the dataset:    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
# 10 last samples of the dataset:       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# Visualisation of the dataset
#
# The coding below shows the visualisation of the dataset in order to understand the data more. It can be seen that every species of the Iris can be segregated into different regions to be predicted.

# %%
sns.lmplot('SepalLengthCm', 'SepalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalLength vs SepalWidth')

sns.lmplot('PetalLengthCm', 'PetalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('PetalLength vs PetalWidth')

sns.lmplot('SepalLengthCm', 'PetalLengthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalLength vs PetalLength')

sns.lmplot('SepalWidthCm', 'PetalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalWidth vs PetalWidth')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Coding below convert the species into each respective category to be feed into the neural network

# %%
print(data["Species"].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
data.loc[data["Species"]=="Iris-setosa","Species"]=0
data.loc[data["Species"]=="Iris-versicolor","Species"]=1
data.loc[data["Species"]=="Iris-virginica","Species"]=2
print(data.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   1            5.1           3.5            1.4           0.2       0
# 1   2            4.9           3.0            1.4           0.2       0
# 2   3            4.7           3.2            1.3           0.2       0
# 3   4            4.6           3.1            1.5           0.2       0
# 4   5            5.0           3.6            1.4           0.2       0

# %%
data=data.iloc[np.random.permutation(len(data))]
print(data.head())
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 9   10            4.9           3.1            1.5           0.1       0
# 29  30            4.7           3.2            1.6           0.2       0
# 32  33            5.2           4.1            1.5           0.1       0
# 19  20            5.1           3.8            1.5           0.3       0
# 42  43            4.4           3.2            1.3           0.2       0

# %% [markdown]
# Converting data to numpy array in order for processing

# %%
X=data.iloc[:,1:5].values
y=data.iloc[:,5].values

print("Shape of X",X.shape)
print("Shape of y",y.shape)
print("Examples of X\n",X[:3])
print("Examples of y\n",y[:3])
# Out:
# Shape of X (150, 4)
# Shape of y (150,)
# Examples of X
#  [[4.9 3.1 1.5 0.1]
#  [4.7 3.2 1.6 0.2]
#  [5.2 4.1 1.5 0.1]]
# Examples of y
#  [0 0 0]

# %% [markdown]
# Normalization
#
# It can be seen from above that the feature of the first dataset has 6cm in Sepal Length, 3.4cm in Sepal Width, 4.5cm in Petal Length and 1.6cm in Petal Width. However, the range of the dataset may be different. Therefore, in order to maintain a good accuracy, the feature of each dataset must be normalized to a range of 0-1 for processing

# %%
X_normalized=normalize(X,axis=0)
print("Examples of X_normalised\n",X_normalized[:3])
# Out:
# Examples of X_normalised
#  [[0.06779548 0.082062   0.02951407 0.0057515 ]
#  [0.06502832 0.08470916 0.03148167 0.01150299]
#  [0.07194622 0.10853361 0.02951407 0.0057515 ]]

# %% [markdown]
# Creating the Train and Test Data by splitting the data into 80% train and 20% test

# %%
#Creating train,test and validation data
'''
80% -- train data
20% -- test data
'''
total_length=len(data)
train_length=int(0.8*total_length)
test_length=int(0.2*total_length)

X_train=X_normalized[:train_length]
X_test=X_normalized[train_length:]
y_train=y[:train_length]
y_test=y[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])
# Out:
# Length of train set x: 120 y: 120
# Length of test set x: 30 y: 30

# %%
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
# from keras.layers.normalization import BatchNormalization 
from keras.utils import np_utils

# %%
#Change the label to one hot vector
'''
[0]--->[1 0 0]
[1]--->[0 1 0]
[2]--->[0 0 1]
'''
y_train=np_utils.to_categorical(y_train,num_classes=3)
y_test=np_utils.to_categorical(y_test,num_classes=3)
print("Shape of y_train",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of y_train (120, 3)
# Shape of y_test (30, 3)

# %%
model=Sequential()
model.add(Dense(1000,input_dim=4,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(300,activation='relu'))
model.add(Dropout(0.2))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 1000)              5000
#
#  dense_13 (Dense)            (None, 500)               500500
#
#  dense_14 (Dense)            (None, 300)               150300
#
#  dropout_5 (Dropout)         (None, 300)               0
#
#  dropout_6 (Dropout)         (None, 300)               0
#
#  dense_15 (Dense)            (None, 3)                 903
#
# =================================================================
# Total params: 656,703
# Trainable params: 656,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=20,epochs=150,verbose=1)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 1s 48ms/step - loss: 1.0877 - accuracy: 0.5333 - val_loss: 1.0621 - val_accuracy: 0.6000
# Epoch 2/150
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0298 - accuracy: 0.6750 - val_loss: 0.9890 - val_accuracy: 0.6000
# Epoch 3/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.9006 - accuracy: 0.7083 - val_loss: 0.8460 - val_accuracy: 0.6000
# Epoch 4/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.
150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0858 - accuracy: 0.9583 - val_loss: 0.1849 - val_accuracy: 0.8667
# Epoch 114/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0654 - accuracy: 0.9750 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 115/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.1338 - accuracy: 0.9500 - val_loss: 0.0875 - val_accuracy: 0.9333
# Epoch 116/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0855 - accuracy: 0.9583 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 117/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0639 - accuracy: 0.9583 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 118/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0783 - accuracy: 0.9500 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 119/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1002 - accuracy: 0.9500 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 120/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0939 - accuracy: 0.9583 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 121/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0700 - accuracy: 0.9667 - val_loss: 0.0752 - val_accuracy: 0.9667
# Epoch 122/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0640 - accuracy: 0.9667 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 123/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0773 - accuracy: 0.9667 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 124/150
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0587 - accuracy: 0.9667 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 125/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0735 - accuracy: 0.9583 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 126/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0582 - accuracy: 0.9750 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 127/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0841 - accuracy: 0.9500 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 128/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0692 - accuracy: 0.9667 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 129/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0528 - accuracy: 0.9833 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 130/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0832 - accuracy: 0.9583 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 131/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0773 - accuracy: 0.9583 - val_loss: 0.0729 - val_accuracy: 0.9667
# Epoch 132/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0648 - accuracy: 0.9583 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 133/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0630 - accuracy: 0.9667 - val_loss: 0.1102 - val_accuracy: 0.9333
# Epoch 134/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0761 - accuracy: 0.9667 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 135/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0846 - accuracy: 0.9500 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 136/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0489 - accuracy: 0.9750 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 137/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0717 - accuracy: 0.9583 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 138/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0662 - accuracy: 0.9667 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 139/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0903 - accuracy: 0.9583 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 140/150
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0611 - accuracy: 0.9667 - val_loss: 0.0850 - val_accuracy: 0.9333
# Epoch 141/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0681 - accuracy: 0.9583 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 142/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.1271 - accuracy: 0.9583 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 143/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1805 - accuracy: 0.9167 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 144/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2140 - accuracy: 0.9167 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 145/150
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0418 - accuracy: 0.9917 - val_loss: 0.3080 - val_accuracy: 0.8667
# Epoch 146/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1442 - accuracy: 0.9333 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 147/150
# 6/6 [==============================] - 0s 17ms/step - loss: 0.1299 - accuracy: 0.9417 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 148/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0977 - accuracy: 0.9500 - val_loss: 0.0973 - val_accuracy: 0.9333
# Epoch 149/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0724 - accuracy: 0.9750 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 150/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0946 - accuracy: 0.9583 - val_loss: 0.0596 - val_accuracy: 1.0000

# %%
prediction=model.predict(X_test)
length=len(prediction)
y_label=np.argmax(y_test,axis=1)
predict_label=np.argmax(prediction,axis=1)

accuracy=np.sum(y_label==predict_label)/length * 100 
print("Accuracy of the dataset",accuracy )
# Out:
# Accuracy of the dataset 100.0

# %% [markdown]
# An accuracy of 100% is achieved in this dataset.It can be asserted that for each epoch, the neural network is trying to learn from its existing feature and predict it by its weights and biases. For each epoch, the weights and biases and changed by subtracting its rate to get a better accuracy each time.
#
# *Further improvement: *
#
# 1.Adding batch normalization
#
# 2.Adding dropout layer to prevent overfitting

# %% [markdown]
# Train vs Test loss

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "r", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Test accuracy")
plt.title("Training and Test accuracy")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Test loss")
plt.title("Training and Test loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# Classification report

# %%
from sklearn.metrics import classification_report

# %%
clas=classification_report(y_label,predict_label)
print(clas)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
